# %%
import requests as req
import pandas as pd
import json

# %%
stations = pd.read_csv('https://raw.githubusercontent.com/arnenewman11/project-one/master/CapitalBikeShareDF.csv')
stations = stations[['start_station','start_date']]
stations['Latitude']=''
stations['Longitude']=''
stations['Neighborhood'] = ''
stations['3 months before']=''
stations['3 months after']=''
stations['6 months before']=''
stations['6 months after']=''
stations['start_station'] = stations.apply(lambda x: x.str.replace(' ','+'))
stations.head()
# Out:
#            start_station        start_date Latitude Longitude Neighborhood  \
# 0         10th+&+e+st+nw   7/12/2012 13:04
# 1  10th+&+florida+ave+nw    10/9/2013 8:55
# 2         10th+&+g+st+nw    10/1/2016 8:41
# 3         10th+&+k+st+nw     7/1/2015 6:32
# 4    10th+&+monroe+st+ne  10/16/2010 13:55
#
#   3 months before 3 months after 6 months before 6 months after
# 0
# 1
# 2
# 3
# 4

# %%
for index, row in stations.iterrows():
    url = 'https://geocoder.cit.api.here.com/6.2/geocode.json'
    app_id = 'YWmtXt51i4qEk4VlEacJ'
    app_code = 'Sna1EDDyBUc7m8EfvgmwMw'
    city = 'Washington'
    street = row['start_station']
    params = {'app_id':app_id,'app_code':app_code,'city':city,'street':street}
    
    response = req.get(url,params).json()
    try:
        lat = response['Response']['View'][0]['Result'][0]['Location']['DisplayPosition']['Latitude']
        lng = response['Response']['View'][0]['Result'][0]['Location']['DisplayPosition']['Longitude']
    
        stations.set_value(index,'Latitude',lat)
        stations.set_value(index,'Longitude',lng)
    except IndexError:
        print('Couldn\'t find coordinates for {0}'.format(street))
    
stations.head()
# Out:
# Couldn't find coordinates for 12th+&+army+navy+dr
# Couldn't find coordinates for 15th+&+n+scott+st
# Couldn't find coordinates for amherst+ave+&+elkins+st
# Couldn't find coordinates for amherst+ave+&+prichard+rd
# Couldn't find coordinates for aurora+hills+community+ctr/18th+&+hayes+st
# Couldn't find coordinates for ballenger+ave+&+dulaney+st
# Couldn't find coordinates for barcroft+community+center
# Couldn't find coordinates for battery+ln+&+trolley+trail
# Couldn't find coordinates for benning+branch+library
# Couldn't find coordinates for bethesda+metro
# Couldn't find coordinates for broschart+&+blackwell+rd
# Couldn't find coordinates for c+&+o+canal+&+wisconsin+ave+nw
# Couldn't find coordinates for congress+heights+metro
# Couldn't find coordinates for court+house+metro+/+15th+&+n+uhle+st
# Couldn't find coordinates for crabbs+branch+way+&+calhoun+pl
# Couldn't find coordinates for crabbs+branch+way+&+redland+rd
# Couldn't find coordinates for crystal+city+metro+/+18th+&+bell+st
# Couldn't find coordinates for deanwood+rec+center
# Couldn't find coordinates for dennis+&+amherst+ave
# Couldn't find coordinates for eastern+market+/+7th+&+north+carolina+ave+se
# Couldn't find coordinates for fairfax+village
# Couldn't find coordinates for fallsgrove+blvd+&+fallsgrove+dr
# Couldn't find coordinates for fenton+st+&+gist+ave
# Couldn't find coordinates for frederick+ave+&+horners+ln
# Couldn't find coordinates for friendship+hts+metro/wisconsin+ave+&+wisconsin+cir
# Couldn't find coordinates for king+farm+blvd+&+piccard+dr
# Couldn't find coordinates for library+st+&+freedom+dr
# Couldn't find coordinates for lyttonsville+rd+&+lyttonsville+pl
# Couldn't find coordinates for maple+&+ritchie+ave
# Couldn't find coordinates for needwood+rd+&+eagles+head+ct
# Couldn't find coordinates for new+hampshire+&+kirklynn+ave
# Couldn't find coordinates for norfolk+&+rugby+ave
# Couldn't find coordinates for pentagon+city+metro+/+12th+&+s+hayes+st
# Couldn't find coordinates for potomac+&+swann+ave
# Couldn't find coordinates for potomac+greens+dr+&+slaters+ln
# Couldn't find coordinates for radford+&+osage+st
# Couldn't find coordinates for reston+regional+library
# Couldn't find coordinates for reston+town+center+transit+station
# Couldn't find coordinates for ripley+&+bonifant+st
# Couldn't find coordinates for rockville+metro+east
# Couldn't find coordinates for rockville+metro+west
# Couldn't find coordinates for royal+&+wilkes+st
# Couldn't find coordinates for s+four+mile+run+&+walter+reed+dr
# Couldn't find coordinates for s+four+mile+run+dr+&+s+shirlington+rd
# Couldn't find coordinates for s+joyce+&+army+navy+dr
# Couldn't find coordinates for saint+asaph+st+&+pendleton++st
# Couldn't find coordinates for shady+grove+metro+east
# Couldn't find coordinates for shady+grove+metro+west
# Couldn't find coordinates for shirlington+transit+center+/+s+quincy+&+randolph+st
# Couldn't find coordinates for sligo+ave+&+carroll+ln
# Couldn't find coordinates for smithsonian-national+mall+/+jefferson+dr+&+12th+st+sw
# Couldn't find coordinates for sunset+hills+&+old+reston+ave
# Couldn't find coordinates for sunset+hills+rd+&+discovery+square
# Couldn't find coordinates for takoma+metro
# Couldn't find coordinates for takoma+park+rec+center
# Couldn't find coordinates for temporary+rd+&+old+reston+ave
# Couldn't find coordinates for town+center+pkwy+&+bowman+towne+dr
# Couldn't find coordinates for town+center+pkwy+&+sunset+hills+rd
# Couldn't find coordinates for tysons+corner+station
# Couldn't find coordinates for tysons+west+transit+center
# Couldn't find coordinates for van+ness+metro+/+udc
# Couldn't find coordinates for windham+ln+&+amherst+ave
# Couldn't find coordinates for woodmont+ave+&+strathmore+st
#            start_station        start_date Latitude Longitude Neighborhood  \
# 0         10th+&+e+st+nw   7/12/2012 13:04  38.6569  -87.1879
# 1  10th+&+florida+ave+nw    10/9/2013 8:55  38.9205   -77.026
# 2         10th+&+g+st+nw    10/1/2016 8:41  38.6569  -87.1879
# 3         10th+&+k+st+nw     7/1/2015 6:32  38.6569  -87.1879
# 4    10th+&+monroe+st+ne  10/16/2010 13:55  38.9324  -76.9959
#
#   3 months before 3 months after 6 months before 6 months after
# 0
# 1
# 2
# 3
# 4

# %%
for index, row in stations.iterrows():
    gkey = 'AIzaSyDCL4okv3TmJwq_KF_kmYx9ZziFcZAgNb0'
    url2 = 'https://maps.googleapis.com/maps/api/geocode/json?'
    lati = row['Latitude']
    lngi = row['Longitude']
    params = {'key':gkey,'latlng':str(lati) + ',' + str(lngi),'result_type':'neighborhood'}
    
    resp = req.get(url2,params=params).json()
    try:
        neigh = resp['results'][0]['address_components'][0]['long_name']
        stations.set_value(index,'Neighborhood',neigh)
    except IndexError:
        print("Couldn't find neighborhood for {0}, {1}".format(lati, lngi))
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for 39.35678, -120.80284
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for 40.18107, -80.25502
# Couldn't find neighborhood for 37.47058, -105.84031
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for 42.7521, -83.06267
# Couldn't find neighborhood for 30.6127, -92.05981
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for 40.76063, -74.97383
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for 33.73468, -82.7447399
# Couldn't find neighborhood for 39.35678, -120.80284
# Couldn't find neighborhood for 33.72407, -82.74202
# Couldn't find neighborhood for 39.7261, -97.0869699
# Couldn't find neighborhood for 39.72301, -77.47453
# Couldn't find neighborhood for 38.54944, -90.99726
# Couldn't find neighborhood for 38.54529, -91.01155
# Couldn't find neighborhood for 42.35686, -73.17132
# Couldn't find neighborhood for 37.46125, -105.86645
# Couldn't find neighborhood for 33.73302, -82.75072
# Couldn't find neighborhood for 40.18912, -80.26638
# Couldn't find neighborhood for 40.18912, -80.26638
# Couldn't find neighborhood for 40.18912, -80.26638
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for 38.5473, -91.0360199
# Couldn't find neighborhood for 43.14364, -72.12855
# Couldn't find neighborhood for 43.14364, -72.12855
# Couldn't find neighborhood for 43.14364, -72.12855
# Couldn't find neighborhood for 40.76227, -74.97571
# Couldn't find neighborhood for 40.7620099, -74.98141
# Couldn't find neighborhood for 38.71387, -78.1459
# Couldn't find neighborhood for 40.7081, -89.41312
# Couldn't find neighborhood for 38.71387, -78.1459
# Couldn't find neighborhood for 38.71387, -78.1459
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for 38.88979, -76.98829
# Couldn't find neighborhood for 40.17597, -80.24071
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for 44.78879, -91.46831
# Couldn't find neighborhood for 38.54944, -90.99726
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for 43.14364, -72.12855
# Couldn't find neighborhood for 39.73878, -75.06354
# Couldn't find neighborhood for 39.73878, -75.06354
# Couldn't find neighborhood for 40.99162, -74.05647
# Couldn't find neighborhood for 40.7081, -89.41312
# Couldn't find neighborhood for 40.18107, -80.25502
# Couldn't find neighborhood for 40.18107, -80.25502
# Couldn't find neighborhood for 40.18839, -80.26206
# Couldn't find neighborhood for 40.12551, -79.84081
# Couldn't find neighborhood for 40.12551, -79.84081
# Couldn't find neighborhood for 40.1240783, -79.8432786
# Couldn't find neighborhood for 40.17977, -80.24204
# Couldn't find neighborhood for 40.70211, -89.393
# Couldn't find neighborhood for 40.75944, -74.99384
# Couldn't find neighborhood for 37.45083, -105.8661
# Couldn't find neighborhood for 40.76063, -74.97383
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for 42.7521, -83.06267
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for 40.17768, -80.23452
# Couldn't find neighborhood for 40.19427, -80.2784099
# Couldn't find neighborhood for 44.81483, -91.3448499
# Couldn't find neighborhood for 40.98513, -79.57153
# Couldn't find neighborhood for 40.70369, -89.44051
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for 40.60279, -76.30222
# Couldn't find neighborhood for 40.18746, -80.26227
# Couldn't find neighborhood for 40.10477, -79.83335
# Couldn't find neighborhood for 41.88967, -80.14691
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for 40.70247, -89.40603
# Couldn't find neighborhood for 40.57002, -76.76208
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for 42.7521, -83.06267
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for 39.74163, -75.0243
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for 39.74163, -75.0243
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for 35.53436, -77.02866
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for 37.46345, -105.86498
# Couldn't find neighborhood for 41.19449, -78.89443
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for 40.1629999, -80.23335
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for 40.60279, -76.30222
# Couldn't find neighborhood for 40.60207, -76.30242
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for 37.53418, -105.5507499
# Couldn't find neighborhood for 35.56244, -77.0279599
# Couldn't find neighborhood for 40.70713, -89.41145
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for 38.51731, -91.02673
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for 40.18886, -80.2591
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for 39.65526, -84.17304
# Couldn't find neighborhood for 41.61728, -73.3209399
# Couldn't find neighborhood for 35.14392, -97.48839
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for 44.70452, -91.34133
# Couldn't find neighborhood for 40.15417, -80.29446
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for 40.17693, -80.25296
# Couldn't find neighborhood for 40.190948, -80.2765997
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for 38.65175, -87.13239
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for 37.46125, -105.86645
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for 38.65121, -87.1582899
# Couldn't find neighborhood for 40.7081, -89.41312
# Couldn't find neighborhood for 40.76091, -74.96826
# Couldn't find neighborhood for 38.88046, -77.0571499
# Couldn't find neighborhood for 38.88046, -77.0571499
# Couldn't find neighborhood for 42.73953, -83.03342
# Couldn't find neighborhood for 38.88046, -77.0571499
# Couldn't find neighborhood for 40.1798, -80.27646
# Couldn't find neighborhood for 42.73953, -83.03342
# Couldn't find neighborhood for 40.98539, -74.0702
# Couldn't find neighborhood for 40.98945, -74.04926
# Couldn't find neighborhood for 35.53806, -77.0428699
# Couldn't find neighborhood for 33.72988, -82.75573
# Couldn't find neighborhood for 33.7721, -93.68758
# Couldn't find neighborhood for 41.19449, -78.89443
# Couldn't find neighborhood for 41.19449, -78.89443
# Couldn't find neighborhood for 41.19449, -78.89443
# Couldn't find neighborhood for 41.19449, -78.89443
# Couldn't find neighborhood for 41.19449, -78.89443
# Couldn't find neighborhood for ,
# Couldn't find neighborhood for ,
#            start_station        start_date Latitude Longitude  \
# 0         10th+&+e+st+nw   7/12/2012 13:04  38.6569  -87.1879
# 1  10th+&+florida+ave+nw    10/9/2013 8:55  38.9205   -77.026
# 2         10th+&+g+st+nw    10/1/2016 8:41  38.6569  -87.1879
# 3         10th+&+k+st+nw     7/1/2015 6:32  38.6569  -87.1879
# 4    10th+&+monroe+st+ne  10/16/2010 13:55  38.9324  -76.9959
#
#        Neighborhood 3 months before 3 months after 6 months before  \
# 0
# 1  Columbia Heights
# 2
# 3
# 4          Edgewood
#
#   6 months after
# 0
# 1
# 2
# 3
# 4

# %%
#neighborhood = stations[stations['Neighborhood'] != ''] 
neighborhood = stations.loc[stations['Neighborhood']!='']
neighborhood.head()
# Out:
#                    start_station        start_date Latitude Longitude  \
# 1          10th+&+florida+ave+nw    10/9/2013 8:55  38.9205   -77.026
# 4            10th+&+monroe+st+ne  10/16/2010 13:55  38.9324  -76.9959
# 6  10th+st+&+constitution+ave+nw   10/7/2010 15:42  38.8921   -77.026
# 7    10th+st+&+l'enfant+plaza+sw   5/19/2016 12:08  38.8836  -77.0249
# 9            11th+&+girard+st+nw     6/8/2017 4:32   38.926  -77.0249
#
#                Neighborhood 3 months before 3 months after 6 months before  \
# 1          Columbia Heights
# 4                  Edgewood
# 6      Northwest Washington
# 7  Southwest Federal Center
# 9           Pleasant Plains
#
#   6 months after
# 1
# 4
# 6
# 7
# 9
